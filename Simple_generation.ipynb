# %%
# %cd image_generation
# Out:
# /home/amin/clevr-custom/image_generation

# %%
# !../blender-4.1.1-linux-x64/blender --background --python render_images_custom.py -- --use_gpu 1  --objs_config data/config.json --num_images 1 --margin 0.01 --width 1024 --height 1024
# Out:
# Blender 4.1.1 (hash e1743a0317bc built 2024-04-15 23:47:45)
# ...

# %%
##two objcet same color same size
# %cd image_generation
import json
with open("data/properties.json", 'r') as f:
    properties = json.load(f)
shapes=list(properties["shapes"].keys())
#shapes=["cone","pyramid"]
for shape1 in shapes:
    for shape2 in shapes:
        if shape1==shape2:
            continue
        color="blue"
        arg_shapes=shape1+" "+shape2
        arg_colors=color+" "+color
        arg_rotates="0,0,0 0,0,0"
        arg_scales="1 1"
        arg_locs="-2.5,2.5 2.5,-2.5"
        # !../blender-4.1.1-linux-x64/blender --background  --python render_images_custom.py -- --use_gpu 1  --objects {arg_shapes}\
             --cobjects {arg_colors} --robjects 0 0 --sobjects 1 1 --objs_config data/TwoObjectSameColor.json  --num_images 1\
             --margin 0.01 --width 1024 --height 1024 --output_image_dir ../output/Two-Object-Same-Color/ 1> /dev/null
# Out:
# /home/amin/clevr-custom/image_generation

# %%
# !cd ../output;zip -r Two-Object-Same-Color.zip Two-Object-Same-Color/
# Out:
#   adding: Two-Object-Same-Color/ (stored 0%)
#   adding: Two-Object-Same-Color/cap-blue_diamond-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color/arrow-blue_moon-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color/pentagon-blue_diamond-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color/sphere-blue_moon-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color/star-blue_cone-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color/mug-blue_cylinder-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color/moon-blue_heart-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color/sphere-blue_star-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color/pentagon-blue_moon-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color/leaf-blue_snowflake-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color/cube-blue_star-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color/cross-blue_mug-blue.png (deflated 0%)
# ...

# %%
##one objcet same color same size
# %cd image_generation
import json
with open("data/properties.json", 'r') as f:
    properties = json.load(f)
shapes=list(properties["shapes"].keys())
#shapes=["cone","pyramid"]
for shape in shapes:
    color="blue"
    arg_shapes=shape
    arg_colors=color
    arg_rotates="0,0,0"
    arg_scales="1"
    # !../blender-4.1.1-linux-x64/blender --background  --python render_images_custom.py -- --use_gpu 1  --objects {arg_shapes}\
            --cobjects {arg_colors} --robjects 0 0 --sobjects 1 1 --objs_config data/OneObject.json  --num_images 1\
            --margin 0.01 --width 1024 --height 1024 --output_image_dir ../output/One-Object/ #1> /dev/null
# Out:
# /home/amin/clevr-custom/image_generation
# Blender 4.1.1 (hash e1743a0317bc built 2024-04-15 23:47:45)
# ...

# %%
# !cd ../output;zip -r One-Object.zip One-Object/
# Out:
#   adding: One-Object/ (stored 0%)
#   adding: One-Object/torus-blue.png (deflated 0%)
#   adding: One-Object/diamond-blue.png (deflated 0%)
#   adding: One-Object/sphere-blue.png (deflated 0%)
#   adding: One-Object/moon-blue.png (deflated 0%)
#   adding: One-Object/cone-blue.png (deflated 0%)
#   adding: One-Object/arrow-blue.png (deflated 0%)
#   adding: One-Object/mug-blue.png (deflated 0%)
#   adding: One-Object/cylinder-blue.png (deflated 0%)
#   adding: One-Object/pot-blue.png (deflated 0%)
#   adding: One-Object/leaf-blue.png (deflated 0%)
#   adding: One-Object/pyramid-blue.png (deflated 0%)
#   adding: One-Object/star-blue.png (deflated 0%)
#   adding: One-Object/cross-blue.png (deflated 0%)
#   adding: One-Object/cube-blue.png (deflated 0%)
#   adding: One-Object/cap-blue.png (deflated 0%)
#   adding: One-Object/pentagon-blue.png (deflated 0%)
#   adding: One-Object/heart-blue.png (deflated 0%)
#   adding: One-Object/snowflake-blue.png (deflated 0%)

# %%
##two objcet same color different size
# %cd image_generation
import json
with open("data/properties.json", 'r') as f:
    properties = json.load(f)
shapes=list(properties["shapes"].keys())
#shapes=["cap","cone"]
for shape1 in shapes:
    for shape2 in shapes:
        if shape1==shape2:
            continue
        color="blue"
        arg_shapes=shape1+" "+shape2
        arg_colors=color+" "+color
        arg_rotates="0,0,0 0,0,0"
        arg_scales="1.8 0.5"
        # !../blender-4.1.1-linux-x64/blender --background  --python render_images_custom.py -- --use_gpu 1  --objects {arg_shapes}\
             --cobjects {arg_colors} --robjects 0 0 --sobjects {arg_scales} --objs_config data/TwoObjectSameColorDiffSize.json  --num_images 1\
             --margin 0.01 --width 1024 --height 1024 --output_image_dir ../output/Two-Object-Same-Color-Diff-Size/ 1> /dev/null
# Out:
# [Errno 2] No such file or directory: 'image_generation'
# /home/amin/clevr-custom/image_generation

# %%
# !cd ../output;zip -r Two-Object-Same-Color-Diff-Size.zip Two-Object-Same-Color-Diff-Size/
# Out:
#   adding: Two-Object-Same-Color-Diff-Size/ (stored 0%)
#   adding: Two-Object-Same-Color-Diff-Size/cap-blue_diamond-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color-Diff-Size/arrow-blue_moon-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color-Diff-Size/pentagon-blue_diamond-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color-Diff-Size/sphere-blue_moon-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color-Diff-Size/star-blue_cone-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color-Diff-Size/mug-blue_cylinder-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color-Diff-Size/moon-blue_heart-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color-Diff-Size/sphere-blue_star-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color-Diff-Size/pentagon-blue_moon-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color-Diff-Size/leaf-blue_snowflake-blue.png (deflated 0%)
#   adding: Two-Object-Same-Color-Diff-Size/cube-blue_star-blue.png (deflated 0%)
# ...

# %%
##two objcet same color different size
# %cd image_generation
import json
with open("data/properties.json", 'r') as f:
    properties = json.load(f)
shapes=list(properties["shapes"].keys())
#shapes=["cone","pyramid"]
for shape1 in shapes:
    for shape2 in shapes:
        if shape1==shape2:
            continue
        color="blue"
        arg_shapes=shape2+" "+shape1
        arg_colors=color+" "+color
        arg_rotates="0,0,0 0,0,0"
        arg_scales="0.5 1.8"
        # !../blender-4.1.1-linux-x64/blender --background  --python render_images_custom.py -- --use_gpu 1  --objects {arg_shapes}\
             --cobjects {arg_colors} --robjects 0 0 --sobjects {arg_scales} --objs_config data/TwoObjectSameColorDiffSize.json  --num_images 1\
             --margin 0.01 --width 1024 --height 1024 --output_image_dir ../output/Two-Object-Same-Color-Diff-Size-RightBig/ 1> /dev/null
# Out:
# [Errno 2] No such file or directory: 'image_generation'
# /home/amin/clevr-custom/image_generation

# %%
# !cd ../output;zip -r Two-Object-Same-Color-Diff-Size.zip Two-Object-Same-Color-Diff-Size/

# %%
##three objcet same color different size
# %cd image_generation
import json
with open("data/properties.json", 'r') as f:
    properties = json.load(f)
shapes=list(properties["shapes"].keys())
shapes=["cone","pyramid","cube"]
for shape1 in shapes:
    for shape2 in shapes:
        for shape3 in shapes:
            if shape1==shape2 or shape2==shape3 or shape1==shape3:
                continue
            color="blue"
            arg_shapes=shape1+" "+shape2+" "+shape3
            arg_colors=color+" "+color+" "+color
            arg_scales="1 1 1"
            # !../blender-4.1.1-linux-x64/blender --background  --python render_images_custom.py -- --use_gpu 1  --objects {arg_shapes}\
                --cobjects {arg_colors} --robjects 0 0 0 --sobjects {arg_scales} --objs_config data/ThreeObjectSameColorSameSize.json  --num_images 1\
                --margin 0.01 --width 1024 --height 1024 --output_image_dir ../output/Three-Object-Same-Color-Same/ #1> /dev/null

# %%
import pandas as pd
df=pd.read_csv("4Object_Names.csv")

# %%
len(df)
# Out:
# 73440

# %%
import random
idx_list=random.sample(range(73440),8000)

# %%
df.iloc[idx_list]
# Out:
#                                 Shapes
# 61346           torus cube cross arrow
# 30418        pyramid diamond arrow pot
# 20733    heart sphere diamond pentagon
# 62692              torus cone mug moon
# 70339         cap pentagon sphere cone
# ...                                ...
# 45491     snowflake cylinder moon star
# 20148             pentagon pot cap mug
# 45642     snowflake mug cylinder torus
# 38708  moon diamond pentagon snowflake
# 4016               cube cap leaf arrow
#
# [8000 rows x 1 columns]

# %%
##four objcet same color different size
# %cd image_generation
import pandas as pd
import json
import random
idx_list=random.sample(range(73440),8000)
import pandas as pd
df=pd.read_csv("4Object_Names.csv")
shame_names=df.iloc[idx_list]["Shapes"]
df.drop(idx_list).to_csv("4Object_Names_Remainder.csv",index=False)
for line in shame_names:
    color="blue"
    arg_shapes=line.split("\n")[0]
    arg_colors=color+" "+color+" "+color+" "+color
    arg_scales="1 1 1 1"
    # !../blender-4.1.1-linux-x64/blender --background  --python render_images_custom.py -- --use_gpu 1  --objects {arg_shapes} --cobjects {arg_colors}\
        --robjects 0 0 0 0 --sobjects {arg_scales} --objs_config data/FourObjectSameColorSameSize.json  --num_images 1\
        --margin 0.01 --width 768 --height 768 --output_image_dir ../output/Four-Object-SameColor-SameSize/ #1> /dev/null
# Out:
# [Errno 2] No such file or directory: 'image_generation'
# /home/amin/clevr-custom/image_generation
# Blender 4.1.1 (hash e1743a0317bc built 2024-04-15 23:47:45)
# ...

# %%
count
# Out:
# 73440

# %%
st="../blender-4.1.1-linux-x64/blender --background  --python render_images_custom.py -- --use_gpu 1  --objects {arg_shapes}\
                --cobjects {arg_colors} --robjects 0 0 0 --sobjects {arg_scales} --objs_config data/ThreeObjectSameColorSameSize.json  --num_images 1\
                --margin 0.01 --width 1024 --height 1024 --output_image_dir ../output/Three-Object-Same-Color-Same/"

# %%
command="../blender-4.1.1-linux-x64/blender --background  --python render_images_custom.py -- --use_gpu 1  --objects %s\
                --cobjects %s --robjects 0 0 0 --sobjects %s --objs_config data/ThreeObjectSameColorSameSize.json  --num_images 1\
                --margin 0.01 --width 1024 --height 1024 --output_image_dir ../output/Three-Object-Same-Color-Same/" % (arg_shapes,arg_colors,arg_scales)

# %%
command
# Out:
# '../blender-4.1.1-linux-x64/blender --background  --python render_images_custom.py -- --use_gpu 1  --objects cube pyramid cone                --cobjects blue blue blue --robjects 0 0 0 --sobjects 1 1 1 --objs_config data/ThreeObjectSameColorSameSize.json  --num_images 1                --margin 0.01 --width 1024 --height 1024 --output_image_dir ../output/Three-Object-Same-Color-Same/'

# %%
list(filter(None,st.split(" ")))
# Out:
# ['../blender-4.1.1-linux-x64/blender',
#  '--background',
#  '--python',
#  'render_images_custom.py',
#  '--',
#  '--use_gpu',
#  '1',
#  '--objects',
#  '{arg_shapes}',
#  '--cobjects',
#  '{arg_colors}',
#  '--robjects',
#  '0',
#  '0',
#  '0',
#  '--sobjects',
#  '{arg_scales}',
#  '--objs_config',
#  'data/ThreeObjectSameColorSameSize.json',
#  '--num_images',
#  '1',
#  '--margin',
#  '0.01',
#  '--width',
#  '1024',
#  '--height',
#  '1024',
#  '--output_image_dir',
#  '../output/Three-Object-Same-Color-Same/']
